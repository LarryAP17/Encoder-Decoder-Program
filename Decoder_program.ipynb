# %% [markdown]
# <a href="https://colab.research.google.com/github/LarryAP17/Encoder-Decoder-Program/blob/main/Decoder_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mapping for encoding
mapping = {
    'a': 'm',
    'b': 'n',
    'c': 'o'
    # Addition section (Aro add koro)
}

# Encoder Func
def encode_text(text):
    return ''.join(mapping.get(char, char) for char in text)

# Decoder Func
def decode_text(text):
    reverse_mapping = {v: k for k, v in mapping.items()}
    return ''.join(reverse_mapping.get(char, char) for char in text)

# Main Menu Func
def main_menu():
    while True:
        print("\n===== Text Encoder/Decoder =====")
        print("1. Encode Text")
        print("2. Decode Text")
        print("3. Quit")

        choice = input("Choose an option (1/2/3): ")

        if choice == '1':
            user_input = input("Enter text to encode: ")
            result = encode_text(user_input)
            print("Encoded Text:", result)

        elif choice == '2':
            user_input = input("Enter text to decode: ")
            result = decode_text(user_input)
            print("Decoded Text:", result)

        elif choice == '3':
            print("Goodbye!")
            break

        else:
            print("Invalid choice. Please select 1, 2, or 3.")

# Run the program
main_menu()
# Out:
# ===== Text Encoder/Decoder =====
# 1. Encode Text
# 2. Decode Text
# 3. Quit
# Choose an option (1/2/3): 1
# Enter text to encode: Visca Barca
# Encoded Text: Visom Bmrom
#
# ===== Text Encoder/Decoder =====
# 1. Encode Text
# 2. Decode Text
# 3. Quit
# Choose an option (1/2/3): 2
# Enter text to decode: Visom Bmrom
# Decoded Text: Visca Barca
#
# ===== Text Encoder/Decoder =====
# 1. Encode Text
# 2. Decode Text
# 3. Quit
# Choose an option (1/2/3): 3
# Goodbye!
